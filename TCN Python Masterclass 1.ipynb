# %%
1 + 1
# Out:
# 2

# %%
2*4 #operators +,*,-,/,
# Out:
# 8

# %% [markdown]
# #operators +,*,-,/,
# Data Types
# Integers: whole numbers
#
# Floats; number with decimals
#
# Objects; numbers, letters, e,g ball, 1000, K, etc.
#
# striings; any object inside this quote mark ".." eg "ball",
#
# The assignment operator =

# %%
A=1 
B=2
C=3
D=4

#Then use all these operators

A+C
D/A
B*C
D-B
# Out:
# 2

# %%
A+C-D/A
B*C/D-B
# Out:
# -0.5

# %% [markdown]
# Brackets in python
#
# Brace or Square [ ]
#
# Curly bracket { }
#
# Parenthesis ( ) for functions

# %%
LT = [a,b,c,d,e,f,g,h]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-2f0a5201ed12> in <module>()
# ----> 1 LT = [a,b,c,d,e,f,g,h]
#
# NameError: name 'a' is not defined

# %%
LT = ["a","b","c","d","e","f","g","h"]

# %%
LT[0]
# Out:
# 'a'

# %%
LT[1]
# Out:
# 'b'

# %%
LT[2]
# Out:
# 'c'

# %%
LT[3]
# Out:
# 'd'

# %%
LT[4]
# Out:
# 'e'

# %%
LT[5]
# Out:
# 'f'

# %%
LT[6]

# %%
LT[7]
# Out:
# 'h'

# %%
LT[0:5]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# #Library technical function that helps to perfrom a particular task
#
# Numerical python is called Numpy
# Pandas is by data wrangling

# %%
import numpy as np
import pandas as pd

# %%
K = pd.read_csv("/content/Laptop Sales.csv")

# %%
k = pd.read_csv("/content/Laptop Sales.csv")
print(k)
# Out:
#     Transaction_date          Product  ...   Latitude   Longitude
# 0        1/2/09 6:17    Silver Laptop  ...  51.500000   -1.116667
# 1        1/2/09 4:53    Silver Laptop  ...  39.195000  -94.681940
# 2       1/2/09 13:08    Silver Laptop  ...  46.188060 -123.830000
# 3       1/3/09 14:44    Silver Laptop  ... -36.133333  144.750000
# 4       1/4/09 12:56      Gold Laptop  ...  33.520560  -86.802500
# ..               ...              ...  ...        ...         ...
# 993    1/22/09 14:25    Silver Laptop  ...  54.583333   -5.933333
# 994     1/28/09 5:36      Gold Laptop  ... -20.360278   57.366111
# 995      1/1/09 4:24  Platinum Laptop  ...  42.946940  -76.429440
# 996     1/8/09 11:55    Silver Laptop  ...  52.083333    0.433333
# 997    1/12/09 21:30    Silver Laptop  ...  43.073060  -89.401110
#
# [998 rows x 12 columns]

# %%
len(k)
# Out:
# 998

# %%
k.dtypes
# Out:
# Transaction_date     object
# Product              object
# Price                object
# Payment_Type         object
# Name                 object
# City                 object
# State                object
# Country              object
# Account_Created      object
# Last_Login           object
# Latitude            float64
# Longitude           float64
# dtype: object

# %%
k.columns
# Out:
# Index(['Transaction_date', 'Product', 'Price', 'Payment_Type', 'Name', 'City',
#        'State', 'Country', 'Account_Created', 'Last_Login', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
k.mean()
# Out:
# Latitude     39.015705
# Longitude   -41.337820
# dtype: float64

# %%
K["City"]
# Out:
# 0                          Basildon
# 1      Parkville
# 2      Astoria
# 3                            Echuca
# 4      Cahaba Heights
#                    ...
# 993                         Belfast
# 994                     Black River
# 995    Skaneateles
# 996                       Haverhill
# 997    Madison
# Name: City, Length: 998, dtype: object

# %%
k["City"].value_counts()
# Out:
# London                          19
# Calgary                         11
# Den Haag                         9
# New York                         9
# Vancouver                        8
#                                 ..
# North Eastham                    1
# Brookline                        1
# Princeton                        1
# Newburgh                         1
# Aardal                           1
# Name: City, Length: 759, dtype: int64

# %%
k.head()
# Out:
#   Transaction_date        Product Price  ...    Last_Login   Latitude   Longitude
# 0      1/2/09 6:17  Silver Laptop  1200  ...   1/2/09 6:08  51.500000   -1.116667
# 1      1/2/09 4:53  Silver Laptop  1200  ...   1/2/09 7:49  39.195000  -94.681940
# 2     1/2/09 13:08  Silver Laptop  1200  ...  1/3/09 12:32  46.188060 -123.830000
# 3     1/3/09 14:44  Silver Laptop  1200  ...  1/3/09 14:22 -36.133333  144.750000
# 4     1/4/09 12:56    Gold Laptop  3600  ...  1/4/09 12:45  33.520560  -86.802500
#
# [5 rows x 12 columns]

# %%
k.head(10)
# Out:
#   Transaction_date        Product Price  ...    Last_Login   Latitude   Longitude
# 0      1/2/09 6:17  Silver Laptop  1200  ...   1/2/09 6:08  51.500000   -1.116667
# 1      1/2/09 4:53  Silver Laptop  1200  ...   1/2/09 7:49  39.195000  -94.681940
# 2     1/2/09 13:08  Silver Laptop  1200  ...  1/3/09 12:32  46.188060 -123.830000
# 3     1/3/09 14:44  Silver Laptop  1200  ...  1/3/09 14:22 -36.133333  144.750000
# 4     1/4/09 12:56    Gold Laptop  3600  ...  1/4/09 12:45  33.520560  -86.802500
# 5     1/4/09 13:19  Silver Laptop  1200  ...  1/4/09 13:04  39.790000  -75.238060
# 6     1/4/09 20:11  Silver Laptop  1200  ...  1/4/09 19:45  40.693610  -89.588890
# 7     1/2/09 20:09  Silver Laptop  1200  ...  1/4/09 20:01  36.343330  -88.850280
# 8     1/4/09 13:17  Silver Laptop  1200  ...  1/4/09 22:10  32.066667   34.766667
# 9     1/4/09 14:11  Silver Laptop  1200  ...   1/5/09 1:17  48.883333    2.150000
#
# [10 rows x 12 columns]

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  998 non-null    object
#  1   Product           998 non-null    object
#  2   Price             998 non-null    object
#  3   Payment_Type      998 non-null    object
#  4   Name              998 non-null    object
#  5   City              998 non-null    object
#  6   State             997 non-null    object
#  7   Country           998 non-null    object
#  8   Account_Created   998 non-null    object
#  9   Last_Login        998 non-null    object
#  10  Latitude          998 non-null    float64
#  11  Longitude         998 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 93.7+ KB

# %%
k["Longitude"].max()
# Out:
# 174.7666667

# %%
k["Country"].value_counts()
# Out:
# United States           463
# United Kingdom          100
# Canada                   76
# Ireland                  49
# Australia                38
# Switzerland              36
# France                   27
# Germany                  25
# Netherlands              22
# Norway                   16
# Italy                    15
# Denmark                  15
# Sweden                   13
# Spain                    12
# Belgium                   8
# Austria                   7
# United Arab Emirates      6
# Turkey                    6
# New Zealand               6
# South Africa              5
# Brazil                    5
# Czech Republic            3
# Hungary                   3
# Poland                    2
# The Bahamas               2
# India                     2
# Philippines               2
# Japan                     2
# Monaco                    2
# Thailand                  2
# Malta                     2
# Finland                   2
# Jersey                    1
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


#for visualization

# %%
#Data Viz with Pandas
# %matplotlib inline

# %%
print(k)
# Out:
#     Transaction_date          Product  ...   Latitude   Longitude
# 0        1/2/09 6:17    Silver Laptop  ...  51.500000   -1.116667
# 1        1/2/09 4:53    Silver Laptop  ...  39.195000  -94.681940
# 2       1/2/09 13:08    Silver Laptop  ...  46.188060 -123.830000
# 3       1/3/09 14:44    Silver Laptop  ... -36.133333  144.750000
# 4       1/4/09 12:56      Gold Laptop  ...  33.520560  -86.802500
# ..               ...              ...  ...        ...         ...
# 993    1/22/09 14:25    Silver Laptop  ...  54.583333   -5.933333
# 994     1/28/09 5:36      Gold Laptop  ... -20.360278   57.366111
# 995      1/1/09 4:24  Platinum Laptop  ...  42.946940  -76.429440
# 996     1/8/09 11:55    Silver Laptop  ...  52.083333    0.433333
# 997    1/12/09 21:30    Silver Laptop  ...  43.073060  -89.401110
#
# [998 rows x 12 columns]

# %%
k.plot.bar()
plt.show()

# %%
x=k["Product"]
y=k["Price"]

plt.figure(figsize = (7, 7))
plt.bar(x,y)
plt.xlabel("Product Type")
plt.ylabel("Price")
plt.title("Product vs Price")
# Out:
# Text(0.5, 1.0, 'Product vs Price')

# %%
k.plot.bar()

# %%
k["Payment_Type"].hist()
